# %%
import pandas as pd

df = pd.read_excel("Dados - Alunos World Gym (respostas).xlsx")
df
# Out:
#        Carimbo de data/hora  \
# 0   2023-06-13 16:46:47.727
# 1   2023-06-13 16:48:08.581
# 2   2023-06-13 16:48:17.491
# 3   2023-06-13 16:48:24.856
# 4   2023-06-13 16:48:26.981
# ..                      ...
# 426 2023-06-14 15:50:28.850
# 427 2023-06-14 15:52:34.985
# 428 2023-06-14 16:00:18.352
# 429 2023-06-14 16:02:08.638
# 430 2023-06-14 16:02:23.551
#
#     Qual o seu nome completo ou número da sua matrícula? A resposta, não-obrigatória, pode nos ajudar a entrar em contato em caso de alguma particularidade.   \
# 0                         Julio César da Silva Junior
# 1                                                  NaN
# 2                                                  NaN
# 3                       Renan Corrêa Alves dos Santos
# 4                       Lucas Araújo Prata Chrisóstomo
# ..                                                 ...
# 426                              isabel  da c p aragao
# 427                  Maria do Socorro Rodrigues Leite
# ...

# %%
df.columns
# Out:
# Index(['Carimbo de data/hora',
#        'Qual o seu nome completo ou número da sua matrícula? A resposta, não-obrigatória, pode nos ajudar a entrar em contato em caso de alguma particularidade. ',
#        'Unidade', 'Idade', 'Gênero', 'Região Administrativa onde mora',
#        'Qual horário do dia, você prefere malhar?',
#        'Quanto dias por semana malha',
#        'Quanto tempo passa na academia, em média (EM MINUTOS)', 'Objetivos',
#        'De quais atividades participa',
#        'Quais novidades você adoraria ver por aqui? Fique à vontade para marcar mais de uma resposta :) ',
#        'Comentário adicional: você mudaria algo na academia? Alguma sugestão de coletivas? Alguma mudança no atendimento? Dica de como tornar a sua experiência insuperável? '],
#       dtype='object')

# %%
rename_dict = {"Carimbo de data/hora":"datetime_stamp",
               "Qual o seu nome completo ou número da sua matrícula? A resposta, não-obrigatória, pode nos ajudar a entrar em contato em caso de alguma particularidade. ":"name",
               "Unidade":"unit","Idade":"age","Gênero":"gender",
               "Região Administrativa onde mora":"RA",
               "Qual horário do dia, você prefere malhar?":"time_of_day",
               "Quanto dias por semana malha":"days_per_week",
               "Quanto tempo passa na academia, em média (EM MINUTOS)":"time_spent_at_gym",
               "Objetivos":"objectives","De quais atividades participa":"activities",
               "Quais novidades você adoraria ver por aqui? Fique à vontade para marcar mais de uma resposta :) ":"requests",
               "Comentário adicional: você mudaria algo na academia? Alguma sugestão de coletivas? Alguma mudança no atendimento? Dica de como tornar a sua experiência insuperável? ":"comment"}

df_ = df.rename(columns=rename_dict)
df_.head()
# Out:
#            datetime_stamp                            name       unit  age  \
# 0 2023-06-13 16:46:47.727    Julio César da Silva Junior        Gama   40
# 1 2023-06-13 16:48:08.581                             NaN  Asa Norte   44
# 2 2023-06-13 16:48:17.491                             NaN  Asa Norte   27
# 3 2023-06-13 16:48:24.856  Renan Corrêa Alves dos Santos      Itapoã   28
# 4 2023-06-13 16:48:26.981  Lucas Araújo Prata Chrisóstomo  Asa Norte   36
#
#   gender          RA time_of_day  days_per_week  time_spent_at_gym  \
# 0  Homem       Gama        Noite              6               80.0
# 1  Homem   Asa Norte       Manhã              5               50.0
# 2  Homem  Asa norte        Noite              5               90.0
# 3  Homem     Paranoa       Manhã              6               40.0
# 4  Homem     Asa Sul       Noite              3               40.0
#
#                                           objectives          activities  \
# ...

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   datetime_stamp     431 non-null    datetime64[ns]
#  1   name               300 non-null    object
#  2   unit               431 non-null    object
#  3   age                431 non-null    int64
#  4   gender             431 non-null    object
#  5   RA                 431 non-null    object
#  6   time_of_day        431 non-null    object
#  7   days_per_week      431 non-null    int64
#  8   time_spent_at_gym  431 non-null    float64
#  9   objectives         431 non-null    object
#  10  activities         431 non-null    object
#  11  requests           431 non-null    object
#  12  comment            277 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(9)
# memory usage: 43.9+ KB

# %%
df_nameless = df_.drop("name", axis=1)
df_nameless.head()
# Out:
#            datetime_stamp       unit  age gender          RA time_of_day  \
# 0 2023-06-13 16:46:47.727       Gama   40  Homem       Gama        Noite
# 1 2023-06-13 16:48:08.581  Asa Norte   44  Homem   Asa Norte       Manhã
# 2 2023-06-13 16:48:17.491  Asa Norte   27  Homem  Asa norte        Noite
# 3 2023-06-13 16:48:24.856     Itapoã   28  Homem     Paranoa       Manhã
# 4 2023-06-13 16:48:26.981  Asa Norte   36  Homem     Asa Sul       Noite
#
#    days_per_week  time_spent_at_gym  \
# 0              6               80.0
# 1              5               50.0
# 2              5               90.0
# 3              6               40.0
# 4              3               40.0
#
#                                           objectives          activities  \
# 0                                      Hipertrofia,   Musculação, Cardio
# 1  Hipertrofia, Hobby, Elevar autoestima e cuidar...  Musculação, Cardio
# 2                   Hipertrofia, Recomendação Médica          Musculação
# ...
